# %%
import pandas as pd
import requests
import hvplot.pandas
from config import geoapify_key

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Single Family Homes

# %%
data = pd.read_csv("Resources/RawSingleFamily_Neighborhood.csv")
#extract only CO data
co_data = data[data['State'] == "CO"]
co_data.head()
# Out:
#      RegionID  SizeRank                  RegionName    RegionType StateName  \
# 112    275471       112  Southeast Colorado Springs  neighborhood        CO
# 121    273540       121       East Colorado Springs  neighborhood        CO
# 122    274771       122  Northeast Colorado Springs  neighborhood        CO
# 123    273201       123    Central Colorado Springs  neighborhood        CO
# 195    268621       198                   Briargate  neighborhood        CO
#
#     State              City                 Metro      CountyName  \
# 112    CO  Colorado Springs  Colorado Springs, CO  El Paso County
# 121    CO  Colorado Springs  Colorado Springs, CO  El Paso County
# 122    CO  Colorado Springs  Colorado Springs, CO  El Paso County
# 123    CO  Colorado Springs  Colorado Springs, CO  El Paso County
# 195    CO  Colorado Springs  Colorado Springs, CO  El Paso County
#
#         2000-01-31  ...     2022-05-31     2022-06-30     2022-07-31  \
# 112  110725.631288  ...  353246.013953  355921.927918  356595.275477
# 121  152578.563676  ...  406938.526026  409023.457025  409060.501212
# 122  178931.355163  ...  469119.862438  471607.932865  471520.326828
# 123  122613.782219  ...  399225.212039  401610.000379  401222.682374
# 195  221376.998851  ...  580258.922678  583199.478548  583062.542914
#
#         2022-08-31     2022-09-30     2022-10-31     2022-11-30  \
# 112  355608.073167  353661.872460  351780.279678  349897.025051
# 121  407739.204381  405632.804675  403776.395427  401849.888875
# 122  469629.939420  466838.821912  464473.508606  462201.793211
# 123  398771.173139  395745.123361  393594.516590  391794.998822
# 195  580394.236304  576322.043089  572696.399635  569441.585752
#
#         2022-12-31     2023-01-31     2023-02-28
# 112  347807.422349  345729.584914  343833.043342
# 121  399950.687498  398333.143770  396716.561489
# 122  459905.896546  457598.670131  455324.309092
# 123  389587.495362  387472.911202  385595.769740
# 195  565857.567255  562587.489715  559927.011649
#
# [5 rows x 287 columns]

# %%
#create new df grouped by city with mean()
city_group_df = co_data.groupby("City").mean().reset_index()

city_group_df
# Out:
#                 City       RegionID      SizeRank     2000-01-31  \
# 0             Arvada  637377.796610  15025.491525  272638.573867
# 1             Aurora  431984.244186  10041.848837  215275.073606
# 2            Boulder  413058.218182  16978.745455  420218.764560
# 3       Breckenridge  119247.000000  25717.000000            NaN
# 4         Broomfield  630394.827586  16243.206897            NaN
# 5        Castle Rock  761538.000000   5049.000000  247329.461184
# 6   Colorado Springs  262342.866667   1880.133333  173929.361679
# 7             Denver  269656.276316   3589.618421  222861.652484
# 8          Englewood  715456.230769  11387.230769  199467.718786
# 9       Fort Collins  658885.828767  16808.246575  238492.138228
# 10            Frisco  119417.000000  23597.000000            NaN
# 11            Golden  303544.000000  11166.000000  246987.287774
# 12          Lakewood  725949.962963   9988.000000  249131.686947
# 13         Littleton  762826.000000   3969.000000  342837.415457
# 14          Longmont  509312.454545   6292.909091  238662.187721
# 15              Mesa   12785.000000  24930.000000  185502.771018
# 16            Parker  619151.041667  16272.583333  343867.910138
# 13         Littleton                           771758.24
# 14          Longmont                           574385.85
# 15              Mesa                           505738.88
# 16            Parker                           848518.77
# 17            Pueblo                           251260.46
# 18          Thornton                           567031.96

# %% [markdown]
# # Top Tier Homes - By City

# %% [markdown]
# ### 65th to 95th Percentile

# %%
top_tier_data = pd.read_csv("Resources/RawTopTierHomes_TimeSeries_City.csv")
co_top_tier_data = top_tier_data[top_tier_data['State'] == 'CO']
co_top_tier_data.head()
# Out:
#      RegionID  SizeRank        RegionName RegionType StateName State  \
# 23      11093        23            Denver       city        CO    CO
# 41       4172        41  Colorado Springs       city        CO    CO
# 52      16846        52            Aurora       city        CO    CO
# 149      4764       149      Fort Collins       city        CO    CO
# 213      5519       214          Lakewood       city        CO    CO
#
#                           Metro        CountyName     2000-01-31  \
# 23   Denver-Aurora-Lakewood, CO     Denver County  326979.950764
# 41         Colorado Springs, CO    El Paso County  265637.747108
# 52   Denver-Aurora-Lakewood, CO   Arapahoe County  285492.957737
# 149            Fort Collins, CO    Larimer County  286064.101742
# 213  Denver-Aurora-Lakewood, CO  Jefferson County  300401.602977
#
#         2000-02-29  ...     2022-05-31     2022-06-30     2022-07-31  \
# 23   328805.411990  ...  942082.164242  949646.149654  947831.933372
# 41   265983.726276  ...  641378.859802  645511.536762  645092.597918
# 52   287298.074916  ...  648935.115881  652842.650925  652493.160057
# 149  285605.423940  ...  760889.575727  766131.382360  764996.759276
# 213  302240.829184  ...  774677.688102  778515.045260  775425.344187
#
#         2022-08-31     2022-09-30     2022-10-31     2022-11-30  \
# 23   937902.898759  924342.955894  914007.662513  907491.517679
# 41   641455.885704  635967.227536  631711.488346  627915.155849
# 52   648421.855444  642484.770682  637178.879709  632583.799977
# 149  758820.457210  751475.537166  746727.951147  744343.606211
# 213  768103.421216  758931.028524  752455.453400  747630.611437
#
#         2022-12-31     2023-01-31     2023-02-28
# 23   901787.132280  896320.040680  889998.443785
# 41   624114.438735  620594.293713  617340.046049
# 52   628188.430099  624015.413908  620786.291844
# 149  742111.131763  739520.631470  737892.085590
# 213  743910.433151  740756.657742  737691.879414
#
# [5 rows x 286 columns]

# %%
#function for pulling desired data from one df and storing in another
def pulldata(df1,df2,colname):
    for index,row in df1.iterrows():
        for index2, row2 in df2.iterrows():
            if row2['RegionName'] == row['City']:
                df1.loc[index,colname] = row2['2023-02-28']
    return df1

# %%
#call function
pulldata(singfam_home_price_city,co_top_tier_data,'Typical Home Price (Top Teir)')

#supress scientific notation and create copy
SingFam_TopTier_combined_df = singfam_home_price_city.round(2).copy()
SingFam_TopTier_combined_df.head()
# Out:
#            City  Typical Home Price (Single Family)  \
# 0        Arvada                           663225.80
# 1        Aurora                           530770.16
# 2       Boulder                          1418469.92
# 3  Breckenridge                          1397773.68
# 4    Broomfield                           774477.19
#
#    Typical Home Price (Top Teir)
# 0                      794293.06
# 1                      620786.29
# 2                     1641210.97
# 3                     2142628.16
# 4                      899867.60

# %% [markdown]
# # Bottom Tier Homes - By City

# %% [markdown]
# ### 5th to 35th Percentile

# %%
bottom_tier_data = pd.read_csv("Resources/RawBottomTierHomes_TimeSeries_City.csv")

# %%
co_bottom_tier_data = bottom_tier_data[bottom_tier_data['State'] == 'CO']
co_bottom_tier_data.head()
# Out:
#      RegionID  SizeRank        RegionName RegionType StateName State  \
# 23      11093        23            Denver       city        CO    CO
# 41       4172        41  Colorado Springs       city        CO    CO
# 52      16846        52            Aurora       city        CO    CO
# 149      4764       149      Fort Collins       city        CO    CO
# 213      5519       214          Lakewood       city        CO    CO
#
#                           Metro        CountyName     2000-01-31  \
# 23   Denver-Aurora-Lakewood, CO     Denver County   84724.067726
# 41         Colorado Springs, CO    El Paso County  102719.000567
# 52   Denver-Aurora-Lakewood, CO   Arapahoe County  100875.814337
# 149            Fort Collins, CO    Larimer County  124124.500566
# 213  Denver-Aurora-Lakewood, CO  Jefferson County  122184.456492
#
#         2000-02-29  ...     2022-05-31     2022-06-30     2022-07-31  \
# 23    85248.100636  ...  393601.604805  397420.554385  398746.646769
# 41   102871.424171  ...  356482.939478  358825.067735  359345.854424
# 52   101540.815499  ...  365438.322270  368844.479603  370385.266282
# 149  124013.978142  ...  418779.992149  421370.047278  421882.092354
# 213  122944.942841  ...  411678.048914  414602.932491  415235.446183
#
#         2022-08-31     2022-09-30     2022-10-31     2022-11-30  \
# 23   397630.428547  395562.230010  393842.559007  392726.937305
# 41   358255.310597  356384.209459  354693.337433  353094.408159
# 52   369817.683477  367919.436946  365804.893727  363902.696561
# 149  420010.675777  417749.862300  416429.994741  416257.026337
# 213  413755.857497  411328.136763  409237.274095  407525.162746
#
#         2022-12-31     2023-01-31     2023-02-28
# 23   391079.216640  390542.067783  390848.486767
# 41   351221.341520  349449.047626  348048.613685
# 52   362015.082418  361190.192055  360939.944917
# 149  415798.204942  415414.570185  415641.790125
# 213  405712.248566  404784.848648  404437.634999
#
# [5 rows x 286 columns]

# %%
pulldata(SingFam_TopTier_combined_df,co_bottom_tier_data, 'Typical Home Price (Bottom Tier)')

combined_df = SingFam_TopTier_combined_df.round(2).copy()
combined_df.head()
# Out:
#            City  Typical Home Price (Single Family)  \
# 0        Arvada                           663225.80
# 1        Aurora                           530770.16
# 2       Boulder                          1418469.92
# 3  Breckenridge                          1397773.68
# 4    Broomfield                           774477.19
#
#    Typical Home Price (Top Teir)  Typical Home Price (Bottom Tier)
# 0                      794293.06                         486501.75
# 1                      620786.29                         360939.94
# 2                     1641210.97                         546725.46
# 3                     2142628.16                         674120.89
# 4                      899867.60                         494302.13

# %% [markdown]
# # Fetching Geocoords from geoapify

# %%
# city_list = combined_df['City'].tolist()

base_url = "https://api.geoapify.com/v1/geocode/search?"

# %%
for index,row in combined_df.iterrows():
    
    city = combined_df.loc[index,"City"]
    city_url = f"{base_url}city={city}&state=CO&apiKey={geoapify_key}"
    
    city_data = requests.get(city_url).json()
    try:
        lat = city_data['features'][0]['properties']['lat']
        lon = city_data['features'][0]['properties']['lon']
        combined_df.loc[index,"Latitude"] = lat
        combined_df.loc[index,"Longitude"] = lon
        print(f"Coords for {city} stored in df")
    except:
        print(f'Error Occured with {city}')
        continue
# Out:
# Coords for Arvada stored in df
# Coords for Aurora stored in df
# Coords for Boulder stored in df
# Coords for Breckenridge stored in df
# Coords for Broomfield stored in df
# Coords for Castle Rock stored in df
# Coords for Colorado Springs stored in df
# Coords for Denver stored in df
# Coords for Englewood stored in df
# Coords for Fort Collins stored in df
# Coords for Frisco stored in df
# Coords for Golden stored in df
# Coords for Lakewood stored in df
# Coords for Littleton stored in df
# Coords for Longmont stored in df
# Coords for Mesa stored in df
# Coords for Parker stored in df
# Coords for Pueblo stored in df
# Coords for Thornton stored in df

# %%
combined_df.to_csv("Resources/CO_SingFam_TopTier_BotTier_Combined.csv")
combined_df
# Out:
#                 City  Typical Home Price (Single Family)  \
# 0             Arvada                           663225.80
# 1             Aurora                           530770.16
# 2            Boulder                          1418469.92
# 3       Breckenridge                          1397773.68
# 4         Broomfield                           774477.19
# 5        Castle Rock                           670136.92
# 6   Colorado Springs                           506916.92
# 7             Denver                           724441.68
# 8          Englewood                           534049.28
# 9       Fort Collins                           619802.66
# 10            Frisco                          1722745.05
# 11            Golden                           694776.49
# 12          Lakewood                           653374.00
# 13         Littleton                           771758.24
# 14          Longmont                           574385.85
# 15              Mesa                           505738.88
# 16            Parker                           848518.77
# 17            Pueblo                           251260.46
# 18          Thornton                           567031.96
#
#     Typical Home Price (Top Teir)  Typical Home Price (Bottom Tier)  \
# 0                       794293.06                         486501.75
# 1                       620786.29                         360939.94
# 2                      1641210.97                         546725.46
# 3                      2142628.16                         674120.89
# 4                       899867.60                         494302.13
# 5                       933674.81                         534250.77
# 6                       617340.05                         348048.61
# 7                       889998.44                         390848.49
# 8                       633196.47                         421651.16
# 9                       737892.09                         415641.79
# 10                     1441888.97                         627068.41
# 11                     1146975.93                         557278.05
# 12                      737691.88                         404437.63
# 13                      992497.59                         491869.96
# 14                      714330.15                         438779.49
# 15                      710747.45                         230685.97
# 16                      884486.76                         564928.61
# 17                      399668.42                         183584.84
# 18                      644318.97                         416745.05
#
#      Latitude   Longitude
# 0   39.800550 -105.081157
# 1   39.740511 -104.830995
# 2   40.014986 -105.270545
# 3   39.482912 -106.046549
# 4   39.940399 -105.052080
# 5   39.372255 -104.858683
# 6   38.833958 -104.825348
# 7   39.739236 -104.984862
# 8   39.648206 -104.987964
# 9   40.550853 -105.066808
# 10  39.574430 -106.097520
# 11  39.754635 -105.220580
# 12  39.708574 -105.084669
# 13  39.613321 -105.016649
# 14  40.167212 -105.101929
# 15  39.166110 -108.139506
# 16  39.518451 -104.761264
# 17  38.254447 -104.609141
# 18  39.869552 -104.985181

# %%
map_plot_1 = combined_df.hvplot.points(
    "Longitude",
    "Latitude",
    geo=True,
    tiles="OSM",
    color = "City",
    size = "Average Home Price (Single Family)",
    scale = .015,
    frame_width = 500, frame_height = 500)

map_plot_1
# Out:
# WARNING:param.GeoPointPlot01567: Specified size dim transform (np.sqrt(dim('Average Home Price (Single Family)'))*0.015) could not be applied, as not all dimensions could be resolved.
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City)
